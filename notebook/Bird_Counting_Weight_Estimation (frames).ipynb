# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ad90c1a0-62df-48f9-89e5-f5346841450c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad90c1a0-62df-48f9-89e5-f5346841450c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install ultralytics opencv-python-headless numpy pandas
# !apt-get install ffmpeg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.8 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
# !pip install ultralytics supervision opencv-python-headless
# !apt-get install ffmpeg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.4/217.4 kB 3.7 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
import os

os.makedirs("frames", exist_ok=True)

# !ffmpeg -i *.MP4 -vf fps=5 frames/frame_%04d.jpg
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !zip -r frames.zip frames
files.download("frames.zip")
# Out:
#   adding: frames/ (stored 0%)
#   adding: frames/frame_0017.jpg (deflated 0%)
#   adding: frames/frame_0033.jpg (deflated 0%)
#   adding: frames/frame_0018.jpg (deflated 0%)
#   adding: frames/frame_0872.jpg (deflated 0%)
#   adding: frames/frame_1354.jpg (deflated 0%)
#   adding: frames/frame_0385.jpg (deflated 0%)
#   adding: frames/frame_0807.jpg (deflated 0%)
#   adding: frames/frame_0477.jpg (deflated 0%)
#   adding: frames/frame_0338.jpg (deflated 0%)
#   adding: frames/frame_0785.jpg (deflated 0%)
#   adding: frames/frame_0895.jpg (deflated 0%)
#   adding: frames/frame_0910.jpg (deflated 0%)
#   adding: frames/frame_0330.jpg (deflated 0%)
#   adding: frames/frame_0086.jpg (deflated 0%)
#   adding: frames/frame_1329.jpg (deflated 0%)
#   adding: frames/frame_0101.jpg (deflated 0%)
#   adding: frames/frame_0419.jpg (deflated 0%)
#   adding: frames/frame_0835.jpg (deflated 0%)
#   adding: frames/frame_0295.jpg (deflated 0%)
#   adding: frames/frame_0599.jpg (deflated 0%)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1e14f453-c156-48b5-9be2-b10681ed78ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e14f453-c156-48b5-9be2-b10681ed78ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip *.zip -d dataset
# !ls dataset
# Out:
# Archive:  Chicken Detection.v1i.yolov8.zip
# caution: filename not matched:  frames.coco.zip
# caution: filename not matched:  frames.zip
